# %% [markdown]
# <a href="https://colab.research.google.com/github/Thiago89ml/Actividad-de-Opiniones/blob/main/Opiniones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.read_csv('dataset_train_95.csv')

# %%
df.head()
# Out:
#        id           autor                                        declaracion  \
# 0  116196  Ciara O'Rourke             CDC just cancelled Halloween for kids.
# 1  118599  Ciara O'Rourke  Coroner saying George Floyd died of drug overd...
# 2  133975   Tom Kertscher  Says Nancy Pelosi made millions in coronavirus...
# 3   92314   Caryn Shinske  New Jersey has "the highest property taxes in ...
# 4   72507  Louis Jacobson  "Nearly 6 out of 10 believe that money and wea...
#
#    etiqueta                          palabras_clave  \
# 0         0               CDC, cancelled, Halloween
# 1         0       George Floyd, died, drug overdose
# 2         0  pelosi, made millions, insider trading
# 3         1      New Jersey, highest property taxes
# 4         1          money, more evenly distributed
#
#                                                tweet  \
# 0  If the CDC wants people to not crowd and party...
# 1  @GlennLoury George Floyd died of a drug overdo...
# ...

# %%
df.shape
# Out:
# (81591, 8)

# %%
df.isnull().sum()
# Out:
# id                               0
# autor                            0
# declaracion                      0
# etiqueta                         0
# palabras_clave                   0
# tweet                            0
# respuesta_mayoria_5_etiquetas    0
# respuesta_mayoria_3_etiquetas    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,  y_train, y_test=train_test_split(df['tweet']+ '' + df['declaracion']+ '' +df['palabras_clave'],df['etiqueta'],test_size=0.01)

# %%
from sklearn.feature_extraction.text import CountVectorizer


vectorizador = CountVectorizer()
x_train_vec = vectorizador.fit_transform(x_train)
x_test_vec = vectorizador.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression()
modelo.fit(x_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

predict = modelo.predict(x_test_vec)
accuracy = accuracy_score(y_test,predict)
print(accuracy)
# Out:
# 1.0

# %%
df_test= pd.read_csv('dataset_test_5_sin_etiqueta.csv')

# %%
df_test.isnull().sum()
# Out:
# id                               0
# autor                            0
# declaracion                      0
# palabras_clave                   0
# tweet                            0
# respuesta_mayoria_5_etiquetas    0
# respuesta_mayoria_3_etiquetas    0
# dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer

nueva= df_test['tweet']+ ' ' +df_test['palabras_clave']+''+df_test['declaracion']
X_nueva = vectorizador.transform(nueva)
resultado= modelo.predict(X_nueva)

df_test['etiqueta']= resultado

df_test.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1243074625.py in <cell line: 0>()
#       2
#       3 nueva= df_test['tweet']+ ' ' +df_test['palabras_clave']+''+df['respuesta_mayoria_5_etiquetas']+''+df_test['declaracion']
# ----> 4 X_nueva = vectorizador.transform(nueva)
#       5 resultado= modelo.predict(X_nueva)
#       6
#
# /usr/local/lib/python3.12/dist-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
#    1419
#    1420         # use the same matrix-building strategy as fit_transform
# -> 1421         _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#    1422         if self.binary:
#    1423             X.data.fill(1)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1261         for doc in raw_documents:
# ...

# %%
output = pd.DataFrame({'id': df_test['id'], 'etiqueta': resultado})
output.to_csv('submission3.csv', index=False)
